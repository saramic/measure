# %%
import pandas as pd

df = pd.read_csv("chicks.csv")
df = df.rename(columns=lambda x: x.strip())
df = df.set_index("name")

df
# Out:
#                              tag  2020-04-14 20:00  2020-04-16 15:00  \
# name
# Fox                          red               0.0              36.4
# Cherry                      blue               0.0              38.7
# Survivor                   white               0.0              42.9
# Mango                     yellow               0.0              42.5
# Snoomy               blue-yellow               0.0              34.4
# Smash                 red-yellow               0.0              32.2
# Chicky                      blue               0.0              32.7
# Grape(light)            blue-red               0.0              35.5
# Chirip(dark)               white               0.0              37.4
# Covid                        red               0.0              36.5
# Nineteen                       -               0.0               0.0
#
#               2020-04-19 13:00  2020-04-23 09:00  2020-04-25 11:00  \
# name
# Fox                       52.0             89.80             112.3
# Cherry                    51.5             77.30              97.3
# Survivor                  63.1             94.04             117.3
# Mango                     61.5             95.70             122.3
# Snoomy                    39.5             68.00              86.1
# Smash                     41.2             63.60              72.4
# Chicky                    40.0             67.90              93.1
# Grape(light)              29.8             54.40              70.8
# Chirip(dark)              52.8             85.10             106.1
# Covid                     41.0             71.20              91.8
# Nineteen                  36.8             62.80              78.5
#
#               2020-05-01 10:20  2020-05-08 11:00
# name
# Fox                        199               300
# Cherry                     165               250
# Survivor                   194               285
# Mango                      200               280
# Snoomy                     136               210
# Smash                      143               230
# Chicky                     157               235
# Grape(light)               135               220
# Chirip(dark)               179               266
# Covid                      156               245
# Nineteen                   132               201

# %%
df_dates = df.drop(columns=['tag'])
df_dates = df_dates.rename(columns=lambda x: pd.to_datetime(x))
df_dates = df_dates.transpose()
df_dates
# Out:
# name                   Fox  Cherry  Survivor  Mango  Snoomy  Smash  Chicky  \
# 2020-04-14 20:00:00    0.0     0.0      0.00    0.0     0.0    0.0     0.0
# 2020-04-16 15:00:00   36.4    38.7     42.90   42.5    34.4   32.2    32.7
# 2020-04-19 13:00:00   52.0    51.5     63.10   61.5    39.5   41.2    40.0
# 2020-04-23 09:00:00   89.8    77.3     94.04   95.7    68.0   63.6    67.9
# 2020-04-25 11:00:00  112.3    97.3    117.30  122.3    86.1   72.4    93.1
# 2020-05-01 10:20:00  199.0   165.0    194.00  200.0   136.0  143.0   157.0
# 2020-05-08 11:00:00  300.0   250.0    285.00  280.0   210.0  230.0   235.0
#
# name                 Grape(light)  Chirip(dark)  Covid  Nineteen
# 2020-04-14 20:00:00           0.0           0.0    0.0       0.0
# 2020-04-16 15:00:00          35.5          37.4   36.5       0.0
# 2020-04-19 13:00:00          29.8          52.8   41.0      36.8
# 2020-04-23 09:00:00          54.4          85.1   71.2      62.8
# 2020-04-25 11:00:00          70.8         106.1   91.8      78.5
# 2020-05-01 10:20:00         135.0         179.0  156.0     132.0
# 2020-05-08 11:00:00         220.0         266.0  245.0     201.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

plt.figure(figsize=(20,14))
plt.plot(df_dates)
plt.legend(df_dates.columns, loc='upper left')
plt.show()
